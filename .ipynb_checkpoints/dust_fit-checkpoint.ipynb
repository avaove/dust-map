# %% [markdown]
# # Fitting Dust Observations

# %% [markdown]
# This notebook is meant to provide the scaffolding for us to explore fitting 2-D and 3-D observations of dust, along with the associated observational effects that go along with it.
#
# Each section of the notebook will be dedicated to a particular type of approach that we're interested in testing out.

# %% [markdown]
# # Problem Overview

# %% [markdown]
# The overarching goal of this project is to try to construct a function $f(\mathbf{x})$ as a function of (2-D or 3-D) position $\mathbf{x}$ that can serve as a good approximation to the underlying dust density field $\rho(\mathbf{x})$. Based on the input data set you'll be generating, this may be of the form
#
# $$ f(\mathbf{x}) \approx \log \rho(\mathbf{x}) $$
#
# in the simplest case,
#
# $$ f(\mathbf{x}) \approx \rho(\mathbf{x}) $$
#
# in the second-simplest case, and
#
# $$ \frac{\partial g(\mathbf{x})}{\partial r} \equiv f(\mathbf{x}) \approx \rho(\mathbf{x})$$
#
# in more realistic cases given $r \equiv ||\mathbf{x} - \mathbf{x}_0||$, where $\mathbf{x}_0$ is our current position.
#
# In this last case, being able to redefine our model in terms of $\mathbf{x} \rightarrow (r, \boldsymbol{\theta})$, where $\boldsymbol{\theta}$ defines the angular position (in either polar or spherical coordinates), may be important to ensuring the behavior of the model as a function of $r$ can be treated differently than in $\boldsymbol{\theta}$. In addition, being able to analytically (rather than numerically) differentiate $g(\mathbf{x})$ would also be useful.
#
# For the rest of the overview, I will assume that we're dealing with the most realistic case (i.e. fitting $g(\mathbf{x})$).

# %% [markdown]
# ## Testing

# %% [markdown]
# We want to benchmark the ultimate performance of any method relative to the true underlying dust density field $\rho(\mathbf{x})$. Since the data we're using is simulated, we have access to these over a grid of positions $\mathbf{X}_{\rm grid} = \{ \mathbf{x}_i \}_{i=1}^{n_{\rm grid}}$ and corresponding dust density estimates $\mathbf{P}_{\rm grid} = \{ \rho_i \}_{i=1}^{n_{\rm grid}} = \{ \rho(\mathbf{x}_i) \}_{i=1}^{n_{\rm grid}}$. The choice of metrics (i.e. loss function or cost function) we will use to start will be the **square error (MSE)** evaluated over the grid in dust density
#
# $$ C_{\rm lin}(\mathbf{X}_{\rm grid}, \mathbf{P}_{\rm grid}) = ||f(\mathbf{X}_{\rm grid}) - \mathbf{P}_{\rm grid}||^2 = \sum_{i=1}^{n_{\rm grid}} |f(\mathbf{x}_i) - \rho(\mathbf{x}_i)|^2 $$
#
# An alternate metric that we will use will be computing the MSE after transforming the predictions using the **hyperbolic arcsine (arcsinh)** function:
#
# $$ C_{\rm asinh}(\mathbf{X}_{\rm grid}, \mathbf{P}_{\rm grid}) = ||{\rm arcsinh}(f(\mathbf{X}_{\rm grid})) - {\rm arcsinh}(\mathbf{P}_{\rm grid})||^2 $$
#
# This function is useful because at large values it behaves logarithmically while at small values it behaves linearly. This means the cost function is less sensitive to the deviations at larger values of $\rho(\mathbf{x})$ while behaving similarly for smaller values (and still permitting negative values, unlike a logarithm).

# %% [markdown]
# In practice, we won't have access to the underlying dust density with real data. Instead, we'll want to bechmark our performance using a hold-out **test set** of $\{ \mathbf{X}_{\rm test}, \mathbf{Y}_{\rm test} \}$, where $\mathbf{Y} = \{ \mathbf{y}_i \}_{i=1}^{n_{\rm test}}$ may not be tracing $\rho(\mathbf{x})$ directly. We'll then want to compare what the cost functions $C_{\rm lin}$ and $C_{\rm asinh}$ look like over both the underlying grid $\mathbf{P}_{\rm grid}$ and the observed test set $\mathbf{Y}_{\rm test}$. We will then try to understand what's going on if there are differences between the two.

# %% [markdown]
# ## Training and Validation

# %% [markdown]
# The fitted function $f(\mathbf{x})$ will be derived using a collection of **training data** $\{ \mathbf{X}_{\rm train}, \mathbf{Y}_{\rm train} \}$ and **validation data** $\{ \mathbf{X}_{\rm valid}, \mathbf{Y}_{\rm valid} \}$. The latter will be useful for making sure that we don't overfit the training data. We will want to train our model using one of the specified cost functions above.

# %% [markdown]
#  # for batch_i in range(BATCH_SIZE):
#     #     for group_i in range(0, MIN_MAX_NEURONS, 2):
#     #         print(logits_np[batch_i][group_i:group_i+2])## Incorporating Errors

# %% [markdown]
# For more realistic data, we will have to deal with errors in both the measured positions $\mathbf{X}$ and the measured values $\mathbf{Y}$. These will give a corresponding set of noisy positions $\tilde{\mathbf{X}} = \{ \tilde{\mathbf{x}}_i \}$ and values $\tilde{\mathbf{Y}} = \{ \tilde{\mathbf{y}}_i \}$. The uncertainties that correspond to these noisy measurements
# are $\boldsymbol{\delta}=\{ \sigma_{r, i} \}$ in the $r$ direction (which translates to uncertainties in $\tilde{\mathbf{x}}_i$) and $\boldsymbol{\epsilon} = \{ \sigma_{y, i} \}$ for the individual $y_i$ values. These then define a set of **probability density functions (PDFs)** $P(\tilde{r}_i | r_i, \sigma_{r,i})$ and $P(\tilde{y}_i | y_i, \sigma_{y,i})$.

# %% [markdown]
# ### Single Observation

# %% [markdown]
# Since we don't know what the true value actually is, the approach we want to take is to the **marginalize** over all possible values. In other words, we want to compute:
#
# $$P(\tilde{\mathbf{x}}_i, \tilde{y}_i | \sigma_{r, i}, \sigma_{y,i}) = \int_{0}^{r} P(\tilde{y}_i | g(r \times \hat{\boldsymbol{\ell}}_i), \sigma_{y, i}) \, P(\tilde{r}_i | r \times \hat{\boldsymbol{\ell}}_i, \sigma_{r, i}) \,{\rm d}r$$
#
# There are a couple things going on in this expression:
# 1. The integral over $r$ means that we want to explore all possible values of $r$ between $0$ and $\infty$.
# 2. For each value of $r$, we compute how likely it is by evaluating the PDF $P(\tilde{r}_i| r, \sigma_{r, i})$.
# 3. Each value of $r$ also corresponds to a given position $\mathbf{x} = r \times \hat{\boldsymbol{\ell}}_i$, where $\hat{\boldsymbol{\ell}}_i$ is the normal vector in the direction of the source $i$.
# 4. This gives a prediction $g(\mathbf{x})$ from our fitted functional form.
# 5. We then evaluate the corresponding PDF $P(\tilde{y}_i | g(\mathbf{x}), \sigma_{y, i})$.
#
# The end result is what's known as the **marginal probability**, which will increase as the function $g(\mathbf{x})$ becomes a better match to the underlying data. Evaluating this integral in a numerically feasible way will be a big part of the challenge incorporating errors into the predictions.

# %% [markdown]
# Note that in the case where we have no measurement uncertainty in $r$, this reduces to
#
# $$P(\mathbf{x}_i, \tilde{y}_i | \sigma_{y,i}) = P(\tilde{y}_i | g(\mathbf{x}_i), \sigma_{y, i})$$

# %% [markdown]
# ### Multiple Observations

# %% [markdown]
# Assuming each star provides an **independent and identically distributed (iid)** set of measurements (i.e. the results don't depend on how the stars are ordered and the observations are independent of each other), the probabilities across all the stars multiply and so we get a total probability of
#
# $$ P(\tilde{\mathbf{X}}, \tilde{\mathbf{Y}} | \boldsymbol{\delta}, \boldsymbol{\epsilon}) = \prod_{i=1}^{n} P(\tilde{\mathbf{x}}_i, \tilde{y}_i | \sigma_{r, i}, \sigma_{y,i}) $$
#
# Most often, it is computationally much easier to deal with the log-probabilities
#
# $$ \log P(\tilde{\mathbf{X}}, \tilde{\mathbf{Y}} | \boldsymbol{\delta}, \boldsymbol{\epsilon}) = \sum_{i=1}^{n} \log P(\tilde{\mathbf{x}}_i, \tilde{y}_i | \sigma_{r, i}, \sigma_{y,i}) $$
#
# This looks somewhat similar to our cost function, and indeed there is a deep connection here between the log-probability of our probabilistic model and the cost function of our original (error-less) model. To make things explicit, we will define a new cost function:
#
# $$ \tilde{C}_{\rm lin}(\tilde{\mathbf{X}}, \tilde{\mathbf{Y}} | \boldsymbol{\delta}, \boldsymbol{\epsilon}) = \log P(\tilde{\mathbf{X}}, \tilde{\mathbf{Y}} | \boldsymbol{\delta}, \boldsymbol{\epsilon}) = \sum_{i=1}^{n} \log \left( \int_{0}^{r} P(\tilde{y}_i | g(r \times \hat{\boldsymbol{\ell}}_i), \sigma_{y, i}) \, P(\tilde{r}_i | r \times \hat{\boldsymbol{\ell}}_i, \sigma_{r, i}) \,{\rm d}r \right) $$
#
# The associated function $\tilde{C}_{\rm asinh}$ is defined analagous to the previous case, where we apply the hyperbolic arcsine transformation to modify our predictions $g(\mathbf{x})$ and the associated observations $\tilde{\mathbf{Y}}$ and errors $\boldsymbol{\delta}$.

# %% [markdown]
# Again, in the case where we have no measurement uncertainty in $r$, the integral goes away and this reduces to
#
# $$ \tilde{C}_{\rm lin}(\mathbf{X}, \tilde{\mathbf{Y}} | \boldsymbol{\epsilon}) = \log P(\mathbf{X}, \tilde{\mathbf{Y}} | \boldsymbol{\epsilon}) = \sum_{i=1}^{n} \log P(\tilde{y}_i | g(\mathbf{x}_i), \sigma_{y, i}) $$
#
# For Gaussian errors (such as the ones we assume), you'll find this expression ends up looking *very* similar to our original cost function.

# %% [markdown]
# ## Summary

# %% [markdown]
# To fit the simulated data, you will need to:
# 1. Define the cost function(s) based on some of the considerations above.
# 2. Load in the training, validation, and testing data.
# 3. Initialize our model.
# 4. Fit the model to the training data, using the validation data to tune additional hyper-parameters of the model if necessary.
# 5. Evaluate the cost function(s) for our best-fit model over the test data and the underlying grid of points. (This may involve differentiating the model.)

# %% [markdown]
# # Preamble

# %%
from imports import *
from loss_functions import *
from loading_data import *
from general_plotting import *
from fixed_bins import * 
from interpolation import *
from neural_network import * 
# plot in-line within the notebook
# %matplotlib inline

# %% [markdown]
# ### Real vs Noisy data plots

# %%
plot_noisy_vs_real_data()

# %% [markdown]
# # Model 1: Fixed Bins

# %% [markdown]
# The simplest model we want to benchmark is the **fixed bin** model. This makes the approximation that we can divide up our area into a few quadrants and that within each quadrant the value of $f(\mathbf{x}) \approx \rho(\mathbf{x})$ is constant. These quadrants can either be in Euclidean $(x, y)$ or polar $(r, \theta)$ coordinates (both have been used in the literature).

# %% [markdown]
# ### Sample 50 Bin Model

# %%
# sample bin model with 50 bins
fig, ax = plt.subplots()
img = ax.imshow(get_bin_model(50), cmap='coolwarm')
fig.colorbar(img, label=r'$\log \rho(x, y)$')
ax.set_xlabel(r'$x$')
ax.set_ylabel(r'$y$')
plt.show()

# %% [markdown]
# ### Sample Loss vs Number of Bins and 3 Panel plot for 100 bins model

# %%
# how loss changes as function of bins
bin_model_lst, loss_lin_vals, loss_asinh_vals = plot_loss_bin_model(1, 100, Xo_samp_test, Yo_test, error = True)
# bin_model_lst, loss_lin_vals, loss_asinh_vals = plot_loss_bin_model(1, 100, Xo_samp_test, Yo_test, error = True)
bin_model = bin_model_lst[15] #bin model with 15 bins

# %%
plot_map_panels(Xo_samp_test, Yo_test, 'bin', bin_model)

# %% [markdown]
# ### Comparing Bin Models from 1 to 100 Bins

# %%
## all bin models generated from 1 to 100 bins
fig = plt.figure(figsize=(6, 6))
nrows = 10
ncols = 10
axes = [fig.add_subplot(nrows, ncols, r * ncols + c) for r in range(1, nrows) for c in range(1, ncols)]
for i,ax in enumerate(axes):
    img = ax.imshow(bin_model_lst[i], cmap='coolwarm')
# remove the x and y ticks
for ax in axes:
    ax.set_xticks([])
    ax.set_yticks([])
    ax.axis('off')
plt.savefig(r'plots/bins-100.png')

# %% [markdown]
# ### Finding Expected Loss using error bars (comparable with graph above)

# %% [markdown]
# The floor for loss graph above is the error we expect. Every datapoint is perturbed by (0.9 - 0.1)/2 = 0.4 on average. Then when squaring that, the expected linear loss for any datapoint is 0.4**2 = 0.16. So the total loss is 0.16 * num datapoints = 0.16 * 2000 = 320
# np.sum(np.square(error_bar)) is the loss we expect if getting perfect predictions.

# %%
print(np.sum(np.square(Ye_test))) # loss we expect if getting perfect predictions? 
print(np.sum(np.square(np.arcsinh(Ye_test))))
# Out:
# 18.148606216061744
# 17.567482429253843

# %% [markdown]
# # Model 2: Interpolation

# %% [markdown]
# We used **smooth interpolation** to generate our data in the first place (based on our underlying **Gaussian Process (GP)** model), so we can also try and derive our estimate for $g(\mathbf{x})$ using the same overall approach. There is also a [TensorFlow implementation](https://www.tensorflow.org/addons/api_docs/python/tfa/image/interpolate_spline) that might be useful as we start modifying the loss function.

# %% [markdown]
# ### Predictions vs True values for smooth = 0

# %%
# sample using interpolation: one example
logdust = interpolate.Rbf(Xo_train[:, 0], Xo_train[:, 1], Yo_train, 
                          function='quintic',  # specific interpolation method
                          smooth=0)  # smoothing parameter (0=exact fit)
# evaluate positions log dust densities
train_pred = logdust(Xo_train[:, 0], Xo_train[:, 1])
val_pred = logdust(Xo_valid[:, 0], Xo_valid[:, 1])  # intrinsic values
test_pred = logdust(Xo_test[:, 0], Xo_test[:, 1]) 

loss_lin_train, loss_asinh_train = loss_lin_np(Yo_train, train_pred), loss_asinh_np(Yo_train, train_pred)
loss_lin_val, loss_asinh_val = loss_lin_np(Yo_valid, val_pred), loss_asinh_np(Yo_valid, val_pred)
loss_lin_test, loss_asinh_test = loss_lin_np(Yo_test, test_pred), loss_asinh_np(Yo_test, test_pred)

# %%
print('lin train, val, test loss: ' + repr(loss_lin_train), repr(loss_lin_val), repr(loss_lin_test))
print('asinh train, val, test loss: ' + repr(loss_asinh_train), repr(loss_asinh_val), repr(loss_asinh_test))
plt.figure(figsize=(4, 4))
plot_pred_vs_true(Xo_samp_test, Yo_test, 'interpolate', logdust, title = 'Testing set: True vs Predicted')
# Out:
# lin train, val, test loss: 0.43637438557240826 5480.962923351418 4637.07628799213
# asinh train, val, test loss: 0.27628246815504665 1461.6840579253922 1454.9684426392769

# %%
plot_map_panels(Xo_samp_test, Yo_test, 'interpolate', logdust)

# %% [markdown]
# ### Loss vs Smooth metric

# %%
print(len(Xo_samp_test), len(Yo_test), len(Xo_samp_test[0]))
plot_interpolate_loss(Xo_samp_test, Yo_test)
# Out:
# 2000 2000 10

# %% [markdown]
# # Model 3: Neural Network

# %% [markdown]
# **Neural networks (NNs)** are really useful at constructing smooth functions to fit complex datasets, and so are also something we also want to explore here. In addition, there is actually a [deep connection](https://arxiv.org/pdf/1711.00165.pdf) between NNs and GPs, where you can show that an infinitely wide NN is equivalent to a GP with a particular kernel. Since our data were generated using a GP, it therefore makes sense to try and fit a (wide) neural network to the data.
#
# (There is also [more recent work](https://arxiv.org/pdf/1912.02803.pdf) in this area since things have moved quickly over the last few years, so we might even be able to explore even more cutting-edge implementations such as "infinite-width" networks if time permits.)

# %%
# just pasted the imports here too to avoid going to the top and running this piece over and over, I will delete after the NN works
from imports import *
from loss_functions import *
from loading_data import *
from general_plotting import *
from fixed_bins import * 
from interpolation import *
from neural_network import * 
# to get access to logdust function
# %run 'simulation.py'
# plot in-line within the notebook
# %matplotlib inline
# Out:
# finished running simulation

# %%
from matplotlib import rcParams
def applyPlotStyle():
    rcParams.update({'xtick.major.pad': '7.0'})
    rcParams.update({'xtick.major.size': '7.5'})
    rcParams.update({'xtick.major.width': '1.5'})
    rcParams.update({'xtick.minor.pad': '7.0'})
    rcParams.update({'xtick.minor.size': '3.5'})
    rcParams.update({'xtick.minor.width': '1.0'})
    rcParams.update({'ytick.major.pad': '7.0'})
    rcParams.update({'ytick.major.size': '7.5'})
    rcParams.update({'ytick.major.width': '1.5'})
    rcParams.update({'ytick.minor.pad': '7.0'})
    rcParams.update({'ytick.minor.size': '3.5'})
    rcParams.update({'ytick.minor.width': '1.0'})
    rcParams.update({'axes.titlepad': '15.0'})
    rcParams.update({'axes.labelpad': '15.0'})
    rcParams.update({'font.size': 20})
    
def applyPlotStyle2():
    matplotlib.rc('text', usetex=True)
    matplotlib.rcParams['text.latex.preamble']=r'\usepackage{amsmath}'
applyPlotStyle()

# %%
# model = keras.models.load_model('models')
def pol2cart(r, theita):
    '''Return cartesian coordinate from polar coordinate'''
    x = r * np.cos(theita)
    y = r * np.sin(theita)
    return [x, y]

def polWithTwise2cart(r, x_over_r, y_over_r):
    '''Return cartesian coordinate from polar coordinate'''
    x = r * x_over_r #np.cos(theita)
    y = r * y_over_r #np.sin(theita)
    return [x, y]

def cart2pol(x, y):
    '''Return polar coordinate from cartesian coordinate'''
    r = np.sqrt(x**2 + y**2)
    phi = np.arctan2(y, x)
    return [r, phi]

def differentiate(model, r, theita):
    '''Return dA(r, phi)/r ie. return predicted integrated dust at (r - delta_r, phi) subtracted from predicted integrated dust at (r, phi)
    note: this is a single data point'''
    pred1 = model(np.array([[r, theita]]), training=False) # NN prediction for integrated dust at r, phi
    pred2 = model(np.array([[r - 1e-5, theita]]), training=False)  # NN prediction for integrated dust at r - delta_r, phi
    return (pred1 - pred2) / 1e-5

# %% [markdown]
# ## Training and Testing a Typical Neural Network with Attenuation Data (Polar coordinates)

# %% [markdown]
# ### Training Network

# %%
# EPOCHS = 20
# BATCH_SIZE = 100
model1, train_loss1, val_loss1 = train_NN_model(error=False)
# Out:
# Start of epo ch 0
# Training loss (for one batch) at step 0: 11.3461
# Seen so far: 50 samples
# Training loss (for one batch) at step 100: 1.4510
# Seen so far: 5050 samples
# Time taken: 7.88s
#
# Start of epo ch 1
# Training loss (for one batch) at step 0: 1.3390
# Seen so far: 50 samples
# Training loss (for one batch) at step 100: 0.9641
# Seen so far: 5050 samples
# Time taken: 7.64s
#
# Start of epo ch 2
# Training loss (for one batch) at step 0: 1.2818
# Seen so far: 50 samples
# Training loss (for one batch) at step 100: 0.9006
# Seen so far: 5050 samples
# Time taken: 7.52s
#
# Start of epo ch 3
# Training loss (for one batch) at step 0: 1.3893
# Seen so far: 50 samples
# Training loss (for one batch) at step 100: 0.9196
# Seen so far: 5050 samples
# Time taken: 7.75s
#
# Start of epo ch 4
# Training loss (for one batch) at step 0: 1.4325
# Seen so far: 50 samples
# Training loss (for one batch) at step 100: 0.8857
# Seen so far: 5050 samples
# Time taken: 7.84s
#
# Start of epo ch 5
# Training loss (for one batch) at step 0: 1.4372
# Seen so far: 50 samples
# Training loss (for one batch) at step 100: 0.8721
# Seen so far: 5050 samples
# Time taken: 7.65s
#
# Start of epo ch 6
# Training loss (for one batch) at step 0: 1.4260
# Seen so far: 50 samples
# Training loss (for one batch) at step 100: 0.8311
# Seen so far: 5050 samples
# Time taken: 7.68s
#
# Start of epo ch 7
# Training loss (for one batch) at step 0: 1.1358
# Seen so far: 50 samples
# Training loss (for one batch) at step 100: 0.8418
# Seen so far: 5050 samples
# Time taken: 7.73s
#
# Start of epo ch 8
# Training loss (for one batch) at step 0: 0.9680
# Seen so far: 50 samples
# Training loss (for one batch) at step 100: 0.8098
# Seen so far: 5050 samples
# Time taken: 8.01s
#
# Start of epo ch 9
# Training loss (for one batch) at step 0: 1.0883
# Seen so far: 50 samples
# Training loss (for one batch) at step 100: 0.7974
# Seen so far: 5050 samples
# Time taken: 7.74s
#
# Start of epo ch 10
# Training loss (for one batch) at step 0: 1.2913
# Seen so far: 50 samples
# Training loss (for one batch) at step 100: 0.6213
# Seen so far: 5050 samples
# Time taken: 8.20s
#
# Start of epo ch 11
# Training loss (for one batch) at step 0: 0.9841
# Seen so far: 50 samples
# Training loss (for one batch) at step 100: 0.5828
# Seen so far: 5050 samples
# Time taken: 8.62s
#
# Start of epo ch 12
# Training loss (for one batch) at step 0: 1.2303
# Seen so far: 50 samples
# Training loss (for one batch) at step 100: 0.5498
# Seen so far: 5050 samples
# Time taken: 7.86s
#
# Start of epo ch 13
# Training loss (for one batch) at step 0: 1.1737
# Seen so far: 50 samples
# Training loss (for one batch) at step 100: 0.5406
# Seen so far: 5050 samples
# Time taken: 7.70s
#
# Start of epo ch 14
# Training loss (for one batch) at step 0: 0.9480
# Seen so far: 50 samples
# Training loss (for one batch) at step 100: 0.4936
# Seen so far: 5050 samples
# Time taken: 7.93s
#
# Start of epo ch 15
# Training loss (for one batch) at step 0: 1.0322
# Seen so far: 50 samples
# Training loss (for one batch) at step 100: 0.5423
# Seen so far: 5050 samples
# Time taken: 7.90s
#
# Start of epo ch 16
# Training loss (for one batch) at step 0: 0.5333
# Seen so far: 50 samples
# Training loss (for one batch) at step 100: 0.5115
# Seen so far: 5050 samples
# Time taken: 7.58s
#
# Start of epo ch 17
# Training loss (for one batch) at step 0: 0.6990
# Seen so far: 50 samples
# Training loss (for one batch) at step 100: 0.5416
# Seen so far: 5050 samples
# Time taken: 7.78s
#
# Start of epo ch 18
# Training loss (for one batch) at step 0: 0.6664
# Seen so far: 50 samples
# Training loss (for one batch) at step 100: 0.4822
# Seen so far: 5050 samples
# Time taken: 7.62s
#
# Start of epo ch 19
# Training loss (for one batch) at step 0: 0.5027
# Seen so far: 50 samples
# Training loss (for one batch) at step 100: 0.4921
# Seen so far: 5050 samples
# Time taken: 7.61s
#
# Start of epo ch 20
# Training loss (for one batch) at step 0: 0.4861
# Seen so far: 50 samples
# Training loss (for one batch) at step 100: 0.4347
# Seen so far: 5050 samples
# Time taken: 7.88s
#
# Start of epo ch 21
# Training loss (for one batch) at step 0: 0.4148
# Seen so far: 50 samples
# Training loss (for one batch) at step 100: 0.3858
# Seen so far: 5050 samples
# Time taken: 7.73s
#
# Start of epo ch 22
# Training loss (for one batch) at step 0: 0.5166
# Seen so far: 50 samples
# Training loss (for one batch) at step 100: 0.3603
# Seen so far: 5050 samples
# Time taken: 7.86s
#
# Start of epo ch 23
# Training loss (for one batch) at step 0: 0.4573
# Seen so far: 50 samples
# Training loss (for one batch) at step 100: 0.2882
# Seen so far: 5050 samples
# Time taken: 7.79s
#
# Start of epo ch 24
# Training loss (for one batch) at step 0: 0.3753
# Seen so far: 50 samples
# Training loss (for one batch) at step 100: 0.2140
# Seen so far: 5050 samples
# Time taken: 8.87s
#
# Start of epo ch 25
# Training loss (for one batch) at step 0: 0.3302
# Seen so far: 50 samples
# Training loss (for one batch) at step 100: 0.1634
# Seen so far: 5050 samples
# Time taken: 7.86s
#
# Start of epo ch 26
# Training loss (for one batch) at step 0: 0.2899
# Seen so far: 50 samples
# Training loss (for one batch) at step 100: 0.1358
# Seen so far: 5050 samples
# Time taken: 9.77s
#
# Start of epo ch 27
# Training loss (for one batch) at step 0: 0.1960
# Seen so far: 50 samples
# Training loss (for one batch) at step 100: 0.1032
# Seen so far: 5050 samples
# Time taken: 8.05s
#
# Start of epo ch 28
# Training loss (for one batch) at step 0: 0.1682
# Seen so far: 50 samples
# Training loss (for one batch) at step 100: 0.0939
# Seen so far: 5050 samples
# Time taken: 7.87s
#
# Start of epo ch 29
# Training loss (for one batch) at step 0: 0.1394
# Seen so far: 50 samples
# Training loss (for one batch) at step 100: 0.0887
# Seen so far: 5050 samples
# Time taken: 8.10s
#
# Start of epo ch 30
# Training loss (for one batch) at step 0: 0.1164
# Seen so far: 50 samples
# Training loss (for one batch) at step 100: 0.0838
# Seen so far: 5050 samples
# Time taken: 8.12s
#
# Start of epo ch 31
# Training loss (for one batch) at step 0: 0.1112
# Seen so far: 50 samples
# Training loss (for one batch) at step 100: 0.0761
# Seen so far: 5050 samples
# Time taken: 7.85s
#
# Start of epo ch 32
# Training loss (for one batch) at step 0: 0.1123
# Seen so far: 50 samples
# Training loss (for one batch) at step 100: 0.0709
# Seen so far: 5050 samples
# Time taken: 8.01s
#
# Start of epo ch 33
# Training loss (for one batch) at step 0: 0.1071
# Seen so far: 50 samples
# Training loss (for one batch) at step 100: 0.0718
# Seen so far: 5050 samples
# Time taken: 8.03s
#
# Start of epo ch 34
# Training loss (for one batch) at step 0: 0.1035
# Seen so far: 50 samples
# Training loss (for one batch) at step 100: 0.0777
# Seen so far: 5050 samples
# Time taken: 8.16s
#
# Start of epo ch 35
# Training loss (for one batch) at step 0: 0.0922
# Seen so far: 50 samples
# Training loss (for one batch) at step 100: 0.0781
# Seen so far: 5050 samples
# Time taken: 8.10s
#
# Start of epo ch 36
# Training loss (for one batch) at step 0: 0.0900
# Seen so far: 50 samples
# Training loss (for one batch) at step 100: 0.0691
# Seen so far: 5050 samples
# Time taken: 7.77s
#
# Start of epo ch 37
# Training loss (for one batch) at step 0: 0.0730
# Seen so far: 50 samples
# Training loss (for one batch) at step 100: 0.0562
# Seen so far: 5050 samples
# Time taken: 7.88s
#
# Start of epo ch 38
# Training loss (for one batch) at step 0: 0.0573
# Seen so far: 50 samples
# Training loss (for one batch) at step 100: 0.0471
# Seen so far: 5050 samples
# Time taken: 7.86s
#
# Start of epo ch 39
# Training loss (for one batch) at step 0: 0.0539
# Seen so far: 50 samples
# Training loss (for one batch) at step 100: 0.0364
# Seen so far: 5050 samples
# Time taken: 7.91s
#
# Start of epo ch 40
# Training loss (for one batch) at step 0: 0.0498
# Seen so far: 50 samples
# Training loss (for one batch) at step 100: 0.0309
# Seen so far: 5050 samples
# Time taken: 8.51s
#
# Start of epo ch 41
# Training loss (for one batch) at step 0: 0.0476
# Seen so far: 50 samples
# Training loss (for one batch) at step 100: 0.0278
# Seen so far: 5050 samples
# Time taken: 11.12s
#
# Start of epo ch 42
# Training loss (for one batch) at step 0: 0.0509
# Seen so far: 50 samples
# Training loss (for one batch) at step 100: 0.0252
# Seen so far: 5050 samples
# Time taken: 8.53s
#
# Start of epo ch 43
# Training loss (for one batch) at step 0: 0.0543
# Seen so far: 50 samples
# Training loss (for one batch) at step 100: 0.0239
# Seen so far: 5050 samples
# Time taken: 8.42s
#
# Start of epo ch 44
# Training loss (for one batch) at step 0: 0.0610
# Seen so far: 50 samples
# Training loss (for one batch) at step 100: 0.0222
# Seen so far: 5050 samples
# Time taken: 8.28s
#
# Start of epo ch 45
# Training loss (for one batch) at step 0: 0.0544
# Seen so far: 50 samples
# Training loss (for one batch) at step 100: 0.0218
# Seen so far: 5050 samples
# Time taken: 7.83s
#
# Start of epo ch 46
# Training loss (for one batch) at step 0: 0.0841
# Seen so far: 50 samples
# Training loss (for one batch) at step 100: 0.0311
# Seen so far: 5050 samples
# Time taken: 7.63s
#
# Start of epo ch 47
# Training loss (for one batch) at step 0: 0.0397
# Seen so far: 50 samples
# Training loss (for one batch) at step 100: 0.0355
# Seen so far: 5050 samples
# Time taken: 7.90s
#
# Start of epo ch 48
# Training loss (for one batch) at step 0: 0.0671
# Seen so far: 50 samples
# Training loss (for one batch) at step 100: 0.0256
# Seen so far: 5050 samples
# Time taken: 7.87s
#
# Start of epo ch 49
# Training loss (for one batch) at step 0: 0.0354
# Seen so far: 50 samples
# Training loss (for one batch) at step 100: 0.0265
# Seen so far: 5050 samples
# Time taken: 7.94s
#
# Start of epo ch 50
# Training loss (for one batch) at step 0: 0.0436
# Seen so far: 50 samples
# Training loss (for one batch) at step 100: 0.0174
# Seen so far: 5050 samples
# Time taken: 7.84s
#
# Start of epo ch 51
# Training loss (for one batch) at step 0: 0.0480
# Seen so far: 50 samples
# Training loss (for one batch) at step 100: 0.0172
# Seen so far: 5050 samples
# Time taken: 7.84s
#
# Start of epo ch 52
# Training loss (for one batch) at step 0: 0.0539
# Seen so far: 50 samples
# Training loss (for one batch) at step 100: 0.0204
# Seen so far: 5050 samples
# Time taken: 8.11s
#
# Start of epo ch 53
# Training loss (for one batch) at step 0: 0.0560
# Seen so far: 50 samples
# Training loss (for one batch) at step 100: 0.0162
# Seen so far: 5050 samples
# Time taken: 7.76s
#
# Start of epo ch 54
# Training loss (for one batch) at step 0: 0.0457
# Seen so far: 50 samples
# Training loss (for one batch) at step 100: 0.0172
# Seen so far: 5050 samples
# Time taken: 8.01s
#
# Start of epo ch 55
# Training loss (for one batch) at step 0: 0.0577
# Seen so far: 50 samples
# Training loss (for one batch) at step 100: 0.0123
# Seen so far: 5050 samples
# Time taken: 8.61s
#
# Start of epo ch 56
# Training loss (for one batch) at step 0: 0.0680
# Seen so far: 50 samples
# Training loss (for one batch) at step 100: 0.0218
# Seen so far: 5050 samples
# Time taken: 8.87s
#
# Start of epo ch 57
# Training loss (for one batch) at step 0: 0.0575
# Seen so far: 50 samples
# Training loss (for one batch) at step 100: 0.0280
# Seen so far: 5050 samples
# Time taken: 9.17s
#
# Start of epo ch 58
# Training loss (for one batch) at step 0: 0.0341
# Seen so far: 50 samples
# Training loss (for one batch) at step 100: 0.0225
# Seen so far: 5050 samples
# Time taken: 9.04s
#
# Start of epo ch 59
# Training loss (for one batch) at step 0: 0.0641
# Seen so far: 50 samples
# Training loss (for one batch) at step 100: 0.0225
# Seen so far: 5050 samples
# Time taken: 8.65s
#
# Start of epo ch 60
# Training loss (for one batch) at step 0: 0.0603
# Seen so far: 50 samples
# Training loss (for one batch) at step 100: 0.0199
# Seen so far: 5050 samples
# Time taken: 8.74s
#
# Start of epo ch 61
# Training loss (for one batch) at step 0: 0.0322
# Seen so far: 50 samples
# Training loss (for one batch) at step 100: 0.0169
# Seen so far: 5050 samples
# Time taken: 8.40s
#
# Start of epo ch 62
# Training loss (for one batch) at step 0: 0.0213
# Seen so far: 50 samples
# Training loss (for one batch) at step 100: 0.0150
# Seen so far: 5050 samples
# Time taken: 8.90s
#
# Start of epo ch 63
# Training loss (for one batch) at step 0: 0.0181
# Seen so far: 50 samples
# Training loss (for one batch) at step 100: 0.0139
# Seen so far: 5050 samples
# Time taken: 8.65s
#
# Start of epo ch 64
# Training loss (for one batch) at step 0: 0.0185
# Seen so far: 50 samples
# Training loss (for one batch) at step 100: 0.0134
# Seen so far: 5050 samples
# Time taken: 8.84s
#
# Start of epo ch 65
# Training loss (for one batch) at step 0: 0.0195
# Seen so far: 50 samples
# Training loss (for one batch) at step 100: 0.0133
# Seen so far: 5050 samples
# Time taken: 8.48s
#
# Start of epo ch 66
# Training loss (for one batch) at step 0: 0.0212
# Seen so far: 50 samples
# Training loss (for one batch) at step 100: 0.0139
# Seen so far: 5050 samples
# Time taken: 8.92s
#
# Start of epo ch 67
# Training loss (for one batch) at step 0: 0.0222
# Seen so far: 50 samples
# Training loss (for one batch) at step 100: 0.0132
# Seen so far: 5050 samples
# Time taken: 8.48s
#
# Start of epo ch 68
# Training loss (for one batch) at step 0: 0.0241
# Seen so far: 50 samples
# Training loss (for one batch) at step 100: 0.0141
# Seen so far: 5050 samples
# Time taken: 8.59s
#
# Start of epo ch 69
# Training loss (for one batch) at step 0: 0.0239
# Seen so far: 50 samples
# Training loss (for one batch) at step 100: 0.0128
# Seen so far: 5050 samples
# Time taken: 10.51s
#
# Start of epo ch 70
# Training loss (for one batch) at step 0: 0.0354
# Seen so far: 50 samples
# Training loss (for one batch) at step 100: 0.0178
# Seen so far: 5050 samples
# Time taken: 9.40s
#
# Start of epo ch 71
# Training loss (for one batch) at step 0: 0.0338
# Seen so far: 50 samples
# Training loss (for one batch) at step 100: 0.0108
# Seen so far: 5050 samples
# Time taken: 9.03s
#
# Start of epo ch 72
# Training loss (for one batch) at step 0: 0.0256
# Seen so far: 50 samples
# Training loss (for one batch) at step 100: 0.0089
# Seen so far: 5050 samples
# Time taken: 8.70s
#
# Start of epo ch 73
# Training loss (for one batch) at step 0: 0.0208
# Seen so far: 50 samples
# Training loss (for one batch) at step 100: 0.0067
# Seen so far: 5050 samples
# Time taken: 8.68s
#
# Start of epo ch 74
# Training loss (for one batch) at step 0: 0.0333
# Seen so far: 50 samples
# Training loss (for one batch) at step 100: 0.0072
# Seen so far: 5050 samples
# Time taken: 8.42s
#
# Start of epo ch 75
# Training loss (for one batch) at step 0: 0.0244
# Seen so far: 50 samples
# Training loss (for one batch) at step 100: 0.0079
# Seen so far: 5050 samples
# Time taken: 8.57s
#
# Start of epo ch 76
# Training loss (for one batch) at step 0: 0.0266
# Seen so far: 50 samples
# Training loss (for one batch) at step 100: 0.0075
# Seen so far: 5050 samples
# Time taken: 8.75s
#
# Start of epo ch 77
# Training loss (for one batch) at step 0: 0.0248
# Seen so far: 50 samples
# Training loss (for one batch) at step 100: 0.0055
# Seen so far: 5050 samples
# Time taken: 8.32s
#
# Start of epo ch 78
# Training loss (for one batch) at step 0: 0.0172
# Seen so far: 50 samples
# Training loss (for one batch) at step 100: 0.0102
# Seen so far: 5050 samples
# Time taken: 8.62s
#
# Start of epo ch 79
# Training loss (for one batch) at step 0: 0.0154
# Seen so far: 50 samples
# Training loss (for one batch) at step 100: 0.0082
# Seen so far: 5050 samples
# Time taken: 8.57s
#
# Start of epo ch 80
# Training loss (for one batch) at step 0: 0.0283
# Seen so far: 50 samples
# Training loss (for one batch) at step 100: 0.0143
# Seen so far: 5050 samples
# Time taken: 8.87s
#
# Start of epo ch 81
# Training loss (for one batch) at step 0: 0.0154
# Seen so far: 50 samples
# Training loss (for one batch) at step 100: 0.0095
# Seen so far: 5050 samples
# Time taken: 8.39s
#
# Start of epo ch 82
# Training loss (for one batch) at step 0: 0.0171
# Seen so far: 50 samples
# Training loss (for one batch) at step 100: 0.0132
# Seen so far: 5050 samples
# Time taken: 8.40s
#
# Start of epo ch 83
# Training loss (for one batch) at step 0: 0.0213
# Seen so far: 50 samples
# Training loss (for one batch) at step 100: 0.0071
# Seen so far: 5050 samples
# Time taken: 8.45s
#
# Start of epo ch 84
# Training loss (for one batch) at step 0: 0.0174
# Seen so far: 50 samples
# Training loss (for one batch) at step 100: 0.0113
# Seen so far: 5050 samples
# Time taken: 8.56s
#
# Start of epo ch 85
# Training loss (for one batch) at step 0: 0.0176
# Seen so far: 50 samples
# Training loss (for one batch) at step 100: 0.0109
# Seen so far: 5050 samples
# Time taken: 8.63s
#
# Start of epo ch 86
# Training loss (for one batch) at step 0: 0.0175
# Seen so far: 50 samples
# Training loss (for one batch) at step 100: 0.0113
# Seen so far: 5050 samples
# Time taken: 9.14s
#
# Start of epo ch 87
# Training loss (for one batch) at step 0: 0.0167
# Seen so far: 50 samples
# Training loss (for one batch) at step 100: 0.0095
# Seen so far: 5050 samples
# Time taken: 9.18s
#
# Start of epo ch 88
# Training loss (for one batch) at step 0: 0.0162
# Seen so far: 50 samples
# Training loss (for one batch) at step 100: 0.0087
# Seen so far: 5050 samples
# Time taken: 8.65s
#
# Start of epo ch 89
# Training loss (for one batch) at step 0: 0.0155
# Seen so far: 50 samples
# Training loss (for one batch) at step 100: 0.0078
# Seen so far: 5050 samples
# Time taken: 8.41s
#
# Start of epo ch 90
# Training loss (for one batch) at step 0: 0.0147
# Seen so far: 50 samples
# Training loss (for one batch) at step 100: 0.0134
# Seen so far: 5050 samples
# Time taken: 8.52s
#
# Start of epo ch 91
# Training loss (for one batch) at step 0: 0.0129
# Seen so far: 50 samples
# Training loss (for one batch) at step 100: 0.0069
# Seen so far: 5050 samples
# Time taken: 8.90s
#
# Start of epo ch 92
# Training loss (for one batch) at step 0: 0.0123
# Seen so far: 50 samples
# Training loss (for one batch) at step 100: 0.0111
# Seen so far: 5050 samples
# Time taken: 9.12s
#
# Start of epo ch 93
# Training loss (for one batch) at step 0: 0.0140
# Seen so far: 50 samples
# Training loss (for one batch) at step 100: 0.0065
# Seen so far: 5050 samples
# Time taken: 9.17s
#
# Start of epo ch 94
# Training loss (for one batch) at step 0: 0.0139
# Seen so far: 50 samples
# Training loss (for one batch) at step 100: 0.0076
# Seen so far: 5050 samples
# Time taken: 8.28s
#
# Start of epo ch 95
# Training loss (for one batch) at step 0: 0.0184
# Seen so far: 50 samples
# Training loss (for one batch) at step 100: 0.0093
# Seen so far: 5050 samples
# Time taken: 8.46s
#
# Start of epo ch 96
# Training loss (for one batch) at step 0: 0.0150
# Seen so far: 50 samples
# Training loss (for one batch) at step 100: 0.0089
# Seen so far: 5050 samples
# Time taken: 8.33s
#
# Start of epo ch 97
# Training loss (for one batch) at step 0: 0.0198
# Seen so far: 50 samples
# Training loss (for one batch) at step 100: 0.0149
# Seen so far: 5050 samples
# Time taken: 9.07s
#
# Start of epo ch 98
# Training loss (for one batch) at step 0: 0.0303
# Seen so far: 50 samples
# Training loss (for one batch) at step 100: 0.0085
# Seen so far: 5050 samples
# Time taken: 8.16s
#
# Start of epo ch 99
# Training loss (for one batch) at step 0: 0.0371
# Seen so far: 50 samples
# Training loss (for one batch) at step 100: 0.0064
# Seen so far: 5050 samples
# Time taken: 8.22s
#
# Start of epo ch 100
# Training loss (for one batch) at step 0: 0.0293
# Seen so far: 50 samples
# Training loss (for one batch) at step 100: 0.0054
# Seen so far: 5050 samples
# Time taken: 8.67s
#
# Start of epo ch 101
# Training loss (for one batch) at step 0: 0.0187
# Seen so far: 50 samples
# Training loss (for one batch) at step 100: 0.0065
# Seen so far: 5050 samples
# Time taken: 8.43s
#
# Start of epo ch 102
# Training loss (for one batch) at step 0: 0.0129
# Seen so far: 50 samples
# Training loss (for one batch) at step 100: 0.0124
# Seen so far: 5050 samples
# Time taken: 8.90s
#
# Start of epo ch 103
# Training loss (for one batch) at step 0: 0.0245
# Seen so far: 50 samples
# Training loss (for one batch) at step 100: 0.0119
# Seen so far: 5050 samples
# Time taken: 8.26s
#
# Start of epo ch 104
# Training loss (for one batch) at step 0: 0.0536
# Seen so far: 50 samples
# Training loss (for one batch) at step 100: 0.0048
# Seen so far: 5050 samples
# Time taken: 8.61s
#
# Start of epo ch 105
# Training loss (for one batch) at step 0: 0.0132
# Seen so far: 50 samples
# Training loss (for one batch) at step 100: 0.0115
# Seen so far: 5050 samples
# Time taken: 8.30s
#
# Start of epo ch 106
# Training loss (for one batch) at step 0: 0.0214
# Seen so far: 50 samples
# Training loss (for one batch) at step 100: 0.0136
# Seen so far: 5050 samples
# Time taken: 8.33s
#
# Start of epo ch 107
# Training loss (for one batch) at step 0: 0.0218
# Seen so far: 50 samples
# Training loss (for one batch) at step 100: 0.0205
# Seen so far: 5050 samples
# Time taken: 8.39s
#
# Start of epo ch 108
# Training loss (for one batch) at step 0: 0.0234
# Seen so far: 50 samples
# Training loss (for one batch) at step 100: 0.0130
# Seen so far: 5050 samples
# Time taken: 8.38s
#
# Start of epo ch 109
# Training loss (for one batch) at step 0: 0.0393
# Seen so far: 50 samples
# Training loss (for one batch) at step 100: 0.0479
# Seen so far: 5050 samples
# Time taken: 8.35s
#
# Start of epo ch 110
# Training loss (for one batch) at step 0: 0.0274
# Seen so far: 50 samples
# Training loss (for one batch) at step 100: 0.0193
# Seen so far: 5050 samples
# Time taken: 8.39s
#
# Start of epo ch 111
# Training loss (for one batch) at step 0: 0.0097
# Seen so far: 50 samples
# Training loss (for one batch) at step 100: 0.0132
# Seen so far: 5050 samples
# Time taken: 9.52s
#
# Start of epo ch 112
# Training loss (for one batch) at step 0: 0.0110
# Seen so far: 50 samples
# Training loss (for one batch) at step 100: 0.0069
# Seen so far: 5050 samples
# Time taken: 8.32s
#
# Start of epo ch 113
# Training loss (for one batch) at step 0: 0.0077
# Seen so far: 50 samples
# Training loss (for one batch) at step 100: 0.0094
# Seen so far: 5050 samples
# Time taken: 8.44s
#
# Start of epo ch 114
# Training loss (for one batch) at step 0: 0.0103
# Seen so far: 50 samples
# Training loss (for one batch) at step 100: 0.0055
# Seen so far: 5050 samples
# Time taken: 8.65s
#
# Start of epo ch 115
# Training loss (for one batch) at step 0: 0.0076
# Seen so far: 50 samples
# Training loss (for one batch) at step 100: 0.0118
# Seen so far: 5050 samples
# Time taken: 8.39s
#
# Start of epo ch 116
# Training loss (for one batch) at step 0: 0.0166
# Seen so far: 50 samples
# Training loss (for one batch) at step 100: 0.0053
# Seen so far: 5050 samples
# Time taken: 8.72s
#
# Start of epo ch 117
# Training loss (for one batch) at step 0: 0.0169
# Seen so far: 50 samples
# Training loss (for one batch) at step 100: 0.0119
# Seen so far: 5050 samples
# Time taken: 8.80s
#
# Start of epo ch 118
# Training loss (for one batch) at step 0: 0.0165
# Seen so far: 50 samples
# Training loss (for one batch) at step 100: 0.0171
# Seen so far: 5050 samples
# Time taken: 11.75s
#
# Start of epo ch 119
# Training loss (for one batch) at step 0: 0.0127
# Seen so far: 50 samples
# Training loss (for one batch) at step 100: 0.0053
# Seen so far: 5050 samples
# Time taken: 13.11s
#
# Start of epo ch 120
# Training loss (for one batch) at step 0: 0.0108
# Seen so far: 50 samples
# Training loss (for one batch) at step 100: 0.0116
# Seen so far: 5050 samples
# Time taken: 11.59s
#
# Start of epo ch 121
# Training loss (for one batch) at step 0: 0.0119
# Seen so far: 50 samples
# Training loss (for one batch) at step 100: 0.0047
# Seen so far: 5050 samples
# Time taken: 10.69s
#
# Start of epo ch 122
# Training loss (for one batch) at step 0: 0.0086
# Seen so far: 50 samples
# Training loss (for one batch) at step 100: 0.0106
# Seen so far: 5050 samples
# Time taken: 8.41s
#
# Start of epo ch 123
# Training loss (for one batch) at step 0: 0.0140
# Seen so far: 50 samples
# Training loss (for one batch) at step 100: 0.0054
# Seen so far: 5050 samples
# Time taken: 8.89s
#
# Start of epo ch 124
# Training loss (for one batch) at step 0: 0.0172
# Seen so far: 50 samples
# Training loss (for one batch) at step 100: 0.0118
# Seen so far: 5050 samples
# Time taken: 9.77s
#
# Start of epo ch 125
# Training loss (for one batch) at step 0: 0.0255
# Seen so far: 50 samples
# Training loss (for one batch) at step 100: 0.0154
# Seen so far: 5050 samples
# Time taken: 8.56s
#
# Start of epo ch 126
# Training loss (for one batch) at step 0: 0.0067
# Seen so far: 50 samples
# Training loss (for one batch) at step 100: 0.0101
# Seen so far: 5050 samples
# Time taken: 7.97s
#
# Start of epo ch 127
# Training loss (for one batch) at step 0: 0.0078
# Seen so far: 50 samples
# Training loss (for one batch) at step 100: 0.0050
# Seen so far: 5050 samples
# Time taken: 7.96s
#
# Start of epo ch 128
# Training loss (for one batch) at step 0: 0.0061
# Seen so far: 50 samples
# Training loss (for one batch) at step 100: 0.0100
# Seen so far: 5050 samples
# Time taken: 7.74s
#
# Start of epo ch 129
# Training loss (for one batch) at step 0: 0.0110
# Seen so far: 50 samples
# Training loss (for one batch) at step 100: 0.0046
# Seen so far: 5050 samples
# Time taken: 4.53s
#
# Start of epo ch 130
# Training loss (for one batch) at step 0: 0.0107
# Seen so far: 50 samples
# Training loss (for one batch) at step 100: 0.0083
# Seen so far: 5050 samples
# Time taken: 4.02s
#
# Start of epo ch 131
# Training loss (for one batch) at step 0: 0.0073
# Seen so far: 50 samples
# Training loss (for one batch) at step 100: 0.0054
# Seen so far: 5050 samples
# Time taken: 4.77s
#
# Start of epo ch 132
# Training loss (for one batch) at step 0: 0.0080
# Seen so far: 50 samples
# Training loss (for one batch) at step 100: 0.0044
# Seen so far: 5050 samples
# Time taken: 5.47s
#
# Start of epo ch 133
# Training loss (for one batch) at step 0: 0.0067
# Seen so far: 50 samples
# Training loss (for one batch) at step 100: 0.0082
# Seen so far: 5050 samples
# Time taken: 5.47s
#
# Start of epo ch 134
# Training loss (for one batch) at step 0: 0.0179
# Seen so far: 50 samples
# Training loss (for one batch) at step 100: 0.0053
# Seen so far: 5050 samples
# Time taken: 6.21s
#
# Start of epo ch 135
# Training loss (for one batch) at step 0: 0.0158
# Seen so far: 50 samples
# Training loss (for one batch) at step 100: 0.0261
# Seen so far: 5050 samples
# Time taken: 5.89s
#
# Start of epo ch 136
# Training loss (for one batch) at step 0: 0.0137
# Seen so far: 50 samples
# Training loss (for one batch) at step 100: 0.0109
# Seen so far: 5050 samples
# Time taken: 5.45s
#
# Start of epo ch 137
# Training loss (for one batch) at step 0: 0.0068
# Seen so far: 50 samples
# Training loss (for one batch) at step 100: 0.0048
# Seen so far: 5050 samples
# Time taken: 5.42s
#
# Start of epo ch 138
# Training loss (for one batch) at step 0: 0.0061
# Seen so far: 50 samples
# Training loss (for one batch) at step 100: 0.0079
# Seen so far: 5050 samples
# Time taken: 5.39s
#
# Start of epo ch 139
# Training loss (for one batch) at step 0: 0.0057
# Seen so far: 50 samples
# Training loss (for one batch) at step 100: 0.0048
# Seen so far: 5050 samples
# Time taken: 5.40s
#
# Start of epo ch 140
# Training loss (for one batch) at step 0: 0.0055
# Seen so far: 50 samples
# Training loss (for one batch) at step 100: 0.0065
# Seen so far: 5050 samples
# Time taken: 6.03s
#
# Start of epo ch 141
# Training loss (for one batch) at step 0: 0.0090
# Seen so far: 50 samples
# Training loss (for one batch) at step 100: 0.0055
# Seen so far: 5050 samples
# Time taken: 6.00s
#
# Start of epo ch 142
# Training loss (for one batch) at step 0: 0.0090
# Seen so far: 50 samples
# Training loss (for one batch) at step 100: 0.0071
# Seen so far: 5050 samples
# Time taken: 6.11s
#
# Start of epo ch 143
# Training loss (for one batch) at step 0: 0.0151
# Seen so far: 50 samples
# Training loss (for one batch) at step 100: 0.0058
# Seen so far: 5050 samples
# Time taken: 7.12s
#
# Start of epo ch 144
# Training loss (for one batch) at step 0: 0.0086
# Seen so far: 50 samples
# Training loss (for one batch) at step 100: 0.0073
# Seen so far: 5050 samples
# Time taken: 6.31s
#
# Start of epo ch 145
# Training loss (for one batch) at step 0: 0.0105
# Seen so far: 50 samples
# Training loss (for one batch) at step 100: 0.0062
# Seen so far: 5050 samples
# Time taken: 5.78s
#
# Start of epo ch 146
# Training loss (for one batch) at step 0: 0.0068
# Seen so far: 50 samples
# Training loss (for one batch) at step 100: 0.0065
# Seen so far: 5050 samples
# Time taken: 5.95s
#
# Start of epo ch 147
# Training loss (for one batch) at step 0: 0.0108
# Seen so far: 50 samples
# Training loss (for one batch) at step 100: 0.0066
# Seen so far: 5050 samples
# Time taken: 6.03s
#
# Start of epo ch 148
# Training loss (for one batch) at step 0: 0.0109
# Seen so far: 50 samples
# Training loss (for one batch) at step 100: 0.0145
# Seen so far: 5050 samples
# Time taken: 5.86s
#
# Start of epo ch 149
# Training loss (for one batch) at step 0: 0.0099
# Seen so far: 50 samples
# Training loss (for one batch) at step 100: 0.0055
# Seen so far: 5050 samples
# Time taken: 6.62s
#
# Start of epo ch 150
# Training loss (for one batch) at step 0: 0.0048
# Seen so far: 50 samples
# Training loss (for one batch) at step 100: 0.0048
# Seen so far: 5050 samples
# Time taken: 5.79s
#
# Start of epo ch 151
# Training loss (for one batch) at step 0: 0.0057
# Seen so far: 50 samples
# Training loss (for one batch) at step 100: 0.0051
# Seen so far: 5050 samples
# Time taken: 6.47s
#
# Start of epo ch 152
# Training loss (for one batch) at step 0: 0.0067
# Seen so far: 50 samples
# Training loss (for one batch) at step 100: 0.0054
# Seen so far: 5050 samples
# Time taken: 5.44s
#
# Start of epo ch 153
# Training loss (for one batch) at step 0: 0.0072
# Seen so far: 50 samples
# Training loss (for one batch) at step 100: 0.0054
# Seen so far: 5050 samples
# Time taken: 6.00s
#
# Start of epo ch 154
# Training loss (for one batch) at step 0: 0.0153
# Seen so far: 50 samples
# Training loss (for one batch) at step 100: 0.0053
# Seen so far: 5050 samples
# Time taken: 5.88s
#
# Start of epo ch 155
# Training loss (for one batch) at step 0: 0.0075
# Seen so far: 50 samples
# Training loss (for one batch) at step 100: 0.0052
# Seen so far: 5050 samples
# Time taken: 5.49s
#
# Start of epo ch 156
# Training loss (for one batch) at step 0: 0.0092
# Seen so far: 50 samples
# Training loss (for one batch) at step 100: 0.0087
# Seen so far: 5050 samples
# Time taken: 5.36s
#
# Start of epo ch 157
# Training loss (for one batch) at step 0: 0.0084
# Seen so far: 50 samples
# Training loss (for one batch) at step 100: 0.0076
# Seen so far: 5050 samples
# Time taken: 5.32s
#
# Start of epo ch 158
# Training loss (for one batch) at step 0: 0.0067
# Seen so far: 50 samples
# Training loss (for one batch) at step 100: 0.0053
# Seen so far: 5050 samples
# Time taken: 5.33s
#
# Start of epo ch 159
# Training loss (for one batch) at step 0: 0.0180
# Seen so far: 50 samples
# Training loss (for one batch) at step 100: 0.0385
# Seen so far: 5050 samples
# Time taken: 5.39s
#
# Start of epo ch 160
# Training loss (for one batch) at step 0: 0.0155
# Seen so far: 50 samples
# Training loss (for one batch) at step 100: 0.0093
# Seen so far: 5050 samples
# Time taken: 5.33s
#
# Start of epo ch 161
# Training loss (for one batch) at step 0: 0.0045
# Seen so far: 50 samples
# Training loss (for one batch) at step 100: 0.0052
# Seen so far: 5050 samples
# Time taken: 5.31s
#
# Start of epo ch 162
# Training loss (for one batch) at step 0: 0.0042
# Seen so far: 50 samples
# Training loss (for one batch) at step 100: 0.0058
# Seen so far: 5050 samples
# Time taken: 5.36s
#
# Start of epo ch 163
# Training loss (for one batch) at step 0: 0.0037
# Seen so far: 50 samples
# Training loss (for one batch) at step 100: 0.0041
# Seen so far: 5050 samples
# Time taken: 5.30s
#
# Start of epo ch 164
# Training loss (for one batch) at step 0: 0.0033
# Seen so far: 50 samples
# Training loss (for one batch) at step 100: 0.0046
# Seen so far: 5050 samples
# Time taken: 6.70s
#
# Start of epo ch 165
# Training loss (for one batch) at step 0: 0.0031
# Seen so far: 50 samples
# Training loss (for one batch) at step 100: 0.0040
# Seen so far: 5050 samples
# Time taken: 5.76s
#
# Start of epo ch 166
# Training loss (for one batch) at step 0: 0.0037
# Seen so far: 50 samples
# Training loss (for one batch) at step 100: 0.0044
# Seen so far: 5050 samples
# Time taken: 5.37s
#
# Start of epo ch 167
# Training loss (for one batch) at step 0: 0.0047
# Seen so far: 50 samples
# Training loss (for one batch) at step 100: 0.0049
# Seen so far: 5050 samples
# Time taken: 5.36s
#
# Start of epo ch 168
# Training loss (for one batch) at step 0: 0.0073
# Seen so far: 50 samples
# Training loss (for one batch) at step 100: 0.0047
# Seen so far: 5050 samples
# Time taken: 6.51s
#
# Start of epo ch 169
# Training loss (for one batch) at step 0: 0.0077
# Seen so far: 50 samples
# Training loss (for one batch) at step 100: 0.0061
# Seen so far: 5050 samples
# Time taken: 5.91s
#
# Start of epo ch 170
# Training loss (for one batch) at step 0: 0.0145
# Seen so far: 50 samples
# Training loss (for one batch) at step 100: 0.0076
# Seen so far: 5050 samples
# Time taken: 5.92s
#
# Start of epo ch 171
# Training loss (for one batch) at step 0: 0.0109
# Seen so far: 50 samples
# Training loss (for one batch) at step 100: 0.0052
# Seen so far: 5050 samples
# Time taken: 6.19s
#
# Start of epo ch 172
# Training loss (for one batch) at step 0: 0.0071
# Seen so far: 50 samples
# Training loss (for one batch) at step 100: 0.0046
# Seen so far: 5050 samples
# Time taken: 5.90s
#
# Start of epo ch 173
# Training loss (for one batch) at step 0: 0.0047
# Seen so far: 50 samples
# Training loss (for one batch) at step 100: 0.0047
# Seen so far: 5050 samples
# Time taken: 5.99s
#
# Start of epo ch 174
# Training loss (for one batch) at step 0: 0.0042
# Seen so far: 50 samples
# Training loss (for one batch) at step 100: 0.0051
# Seen so far: 5050 samples
# Time taken: 5.88s
#
# Start of epo ch 175
# Training loss (for one batch) at step 0: 0.0036
# Seen so far: 50 samples
# Training loss (for one batch) at step 100: 0.0052
# Seen so far: 5050 samples
# Time taken: 6.00s
#
# Start of epo ch 176
# Training loss (for one batch) at step 0: 0.0036
# Seen so far: 50 samples
# Training loss (for one batch) at step 100: 0.0050
# Seen so far: 5050 samples
# Time taken: 5.94s
#
# Start of epo ch 177
# Training loss (for one batch) at step 0: 0.0035
# Seen so far: 50 samples
# Training loss (for one batch) at step 100: 0.0056
# Seen so far: 5050 samples
# Time taken: 5.82s
#
# Start of epo ch 178
# Training loss (for one batch) at step 0: 0.0036
# Seen so far: 50 samples
# Training loss (for one batch) at step 100: 0.0044
# Seen so far: 5050 samples
# Time taken: 6.06s
#
# Start of epo ch 179
# Training loss (for one batch) at step 0: 0.0042
# Seen so far: 50 samples
# Training loss (for one batch) at step 100: 0.0094
# Seen so far: 5050 samples
# Time taken: 6.26s
#
# Start of epo ch 180
# Training loss (for one batch) at step 0: 0.0046
# Seen so far: 50 samples
# Training loss (for one batch) at step 100: 0.0038
# Seen so far: 5050 samples
# Time taken: 6.05s
#
# Start of epo ch 181
# Training loss (for one batch) at step 0: 0.0043
# Seen so far: 50 samples
# Training loss (for one batch) at step 100: 0.0083
# Seen so far: 5050 samples
# Time taken: 5.97s
#
# Start of epo ch 182
# Training loss (for one batch) at step 0: 0.0051
# Seen so far: 50 samples
# Training loss (for one batch) at step 100: 0.0048
# Seen so far: 5050 samples
# Time taken: 6.03s
#
# Start of epo ch 183
# Training loss (for one batch) at step 0: 0.0036
# Seen so far: 50 samples
# Training loss (for one batch) at step 100: 0.0056
# Seen so far: 5050 samples
# Time taken: 6.00s
#
# Start of epo ch 184
# Training loss (for one batch) at step 0: 0.0029
# Seen so far: 50 samples
# Training loss (for one batch) at step 100: 0.0044
# Seen so far: 5050 samples
# Time taken: 6.94s
#
# Start of epo ch 185
# Training loss (for one batch) at step 0: 0.0031
# Seen so far: 50 samples
# Training loss (for one batch) at step 100: 0.0045
# Seen so far: 5050 samples
# Time taken: 6.22s
#
# Start of epo ch 186
# Training loss (for one batch) at step 0: 0.0030
# Seen so far: 50 samples
# Training loss (for one batch) at step 100: 0.0043
# Seen so far: 5050 samples
# Time taken: 6.10s
#
# Start of epo ch 187
# Training loss (for one batch) at step 0: 0.0034
# Seen so far: 50 samples
# Training loss (for one batch) at step 100: 0.0043
# Seen so far: 5050 samples
# Time taken: 5.87s
#
# Start of epo ch 188
# Training loss (for one batch) at step 0: 0.0035
# Seen so far: 50 samples
# Training loss (for one batch) at step 100: 0.0052
# Seen so far: 5050 samples
# Time taken: 6.08s
#
# Start of epo ch 189
# Training loss (for one batch) at step 0: 0.0044
# Seen so far: 50 samples
# Training loss (for one batch) at step 100: 0.0057
# Seen so far: 5050 samples
# Time taken: 6.08s
#
# Start of epo ch 190
# Training loss (for one batch) at step 0: 0.0046
# Seen so far: 50 samples
# Training loss (for one batch) at step 100: 0.0056
# Seen so far: 5050 samples
# Time taken: 7.29s
#
# Start of epo ch 191
# Training loss (for one batch) at step 0: 0.0048
# Seen so far: 50 samples
# Training loss (for one batch) at step 100: 0.0060
# Seen so far: 5050 samples
# Time taken: 6.88s
#
# Start of epo ch 192
# Training loss (for one batch) at step 0: 0.0052
# Seen so far: 50 samples
# Training loss (for one batch) at step 100: 0.0047
# Seen so far: 5050 samples
# Time taken: 6.52s
#
# Start of epo ch 193
# Training loss (for one batch) at step 0: 0.0053
# Seen so far: 50 samples
# Training loss (for one batch) at step 100: 0.0063
# Seen so far: 5050 samples
# Time taken: 6.42s
#
# Start of epo ch 194
# Training loss (for one batch) at step 0: 0.0088
# Seen so far: 50 samples
# Training loss (for one batch) at step 100: 0.0048
# Seen so far: 5050 samples
# Time taken: 6.10s
#
# Start of epo ch 195
# Training loss (for one batch) at step 0: 0.0075
# Seen so far: 50 samples
# Training loss (for one batch) at step 100: 0.0058
# Seen so far: 5050 samples
# Time taken: 6.07s
#
# Start of epo ch 196
# Training loss (for one batch) at step 0: 0.0124
# Seen so far: 50 samples
# Training loss (for one batch) at step 100: 0.0065
# Seen so far: 5050 samples
# Time taken: 7.43s
#
# Start of epo ch 197
# Training loss (for one batch) at step 0: 0.0089
# Seen so far: 50 samples
# Training loss (for one batch) at step 100: 0.0056
# Seen so far: 5050 samples
# Time taken: 6.73s
#
# Start of epo ch 198
# Training loss (for one batch) at step 0: 0.0065
# Seen so far: 50 samples
# Training loss (for one batch) at step 100: 0.0042
# Seen so far: 5050 samples
# Time taken: 5.97s
#
# Start of epo ch 199
# Training loss (for one batch) at step 0: 0.0051
# Seen so far: 50 samples
# Training loss (for one batch) at step 100: 0.0067
# Seen so far: 5050 samples
# Time taken: 6.09s

# %%
model1.save("my_model")
# Out:
# INFO:tensorflow:Assets written to: my_model/assets

# %%
plt.figure(figsize=(7, 7)) 
plt.plot(train_loss1, label='Training loss', color='blue', linestyle='-', linewidth = 1, marker = 'o', ms = 2, markeredgecolor='black', markeredgewidth=0.2)
plt.plot(val_loss1, label='Validation loss', color='red', linestyle='dashed', linewidth = 1, marker = 'o', ms = 2, markeredgecolor='black', markeredgewidth=0.2)
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)
plt.title('Training and Validation Loss')
# Out:
# Text(0.5, 1.0, 'Training and Validation Loss')

# %% [markdown]
# ### Testing: Comparing Networks Predicted Data and Intrinsic Data $A(r, \theta)$

# %%
plt.figure(figsize=(15, 8))
#plotting the loss as a function of log A on the x and y axes. This helps to stretch out the axes, since the errors scale proportional to A
rcParams.update({'font.size': 20})
pred = get_NN_pred(model1, X_test)
pred_asinh = np.arcsinh(pred)
Y_test_asinh = np.arcsinh(Y_test)
plt.subplot(1, 2, 1)
plt.scatter(Y_test, pred, s=1, color='blue', linestyle='-', linewidth = 0.2, marker = 'D', edgecolor='black') 
plt.xlabel("Intrinsic " + r'$A(r, \theta)$')
plt.ylabel("Predicted " + r'$A(r, \theta)$')
lims = [min(np.amin(Y_test), np.amin(pred)), max(np.amax(Y_test), np.amax(pred))]
plt.xlim(lims)
plt.ylim(lims)
plt.plot(lims, lims)
plt.title('Intrinsic vs Predicted Data ' +  r'$A(r, \theta)$')
plt.subplot(1, 2, 2)
plt.scatter(Y_test_asinh, pred_asinh, s=1, color='blue', linestyle='-', linewidth = 0.2, marker = 'D', edgecolor='black') 
plt.xlabel("Intrinsic " + r'$asinh A(r, \theta)$')
plt.ylabel("Predicted " + r'$asinh A(r, \theta)$')
lims = [min(np.amin(Y_test_asinh), np.amin(pred_asinh)), max(np.amax(Y_test_asinh), np.amax(pred_asinh))]
plt.xlim(lims)
plt.ylim(lims)
plt.plot(lims, lims)
plt.title('Intrinsic vs Predicted Data ' +  r'$asinh A(r, \theta)$')
plt.tight_layout(pad=3.0)
plt.savefig('plots/typicalintrinsicvspredicted1.png', bbox_inches='tight')

# %% [markdown]
# ### Testing: Comparing Intrinsic, Predicted, Residual Data $A(r, \theta)$

# %%
X_test_cart = np.array([np.array(pol2cart(r,theita)) for r,theita in X_test])
xlim, ylim = [X_MIN, X_MAX], [Y_MIN, Y_MAX]
rcParams.update({'font.size': 30})
applyPlotStyle2()
fig, ax = plt.subplots(1, 3, figsize=(40,10))
pcm = ax[0].scatter(X_test_cart[:, 0], X_test_cart[:, 1], c=Y_test, norm=matplotlib.colors.PowerNorm(gamma=.4), cmap='coolwarm', s = 15)
ax[0].set_xlabel(r'$x$')
ax[0].set_ylabel(r'$y$')
ax[0].set_xlim(xlim)
ax[0].set_ylim(ylim)
ax[0].set_title('Intrinsic Data')
fig.colorbar(pcm, ax=ax[0], label=r'$A_i(x, y)$') 
# im = plt.imshow(X_test_cart, cmap='coolwarm')
pcm = ax[1].scatter(X_test_cart[:, 0], X_test_cart[:, 1], c=pred, norm=matplotlib.colors.PowerNorm(gamma=.4), cmap='coolwarm', s = 15)
ax[1].set_xlabel(r'$x$')
ax[1].set_ylabel(r'$y$')
ax[1].set_xlim(xlim)
ax[1].set_ylim(ylim)
ax[1].set_title('Predicted Data')
fig.colorbar(pcm, ax=ax[1], label=r'$A_p(x, y)$') 
pcm = ax[2].scatter(np.append(X_test_cart[:, 0], [-5, -5]), np.append(X_test_cart[:, 1], [-5, -5]), c=np.append(Y_test - pred,(-4.7967, 4.7967)), cmap='coolwarm', s = 15)
ax[2].set_xlabel(r'$x$')
ax[2].set_ylabel(r'$y$')
ax[2].set_xlim(xlim)
ax[2].set_ylim(ylim)
ax[2].set_title('Residual')
fig.colorbar(pcm, ax=ax[2], label=r'$A_i(x, y) - A_p(x, y)$') 
plt.tight_layout()
plt.savefig('plots/3panelall1.png', bbox_inches='tight')

# %% [markdown]
# ### Testing: Comparing Networks Predicted Data and Intrinsic Data $\dfrac{d A(r, \theta)}{dr}$ using finite difference

# %%
def differentiate4(model, r, theita):
    '''Return dA(r, phi)/r ie. return predicted integrated dust at (r - delta_r, phi) subtracted from predicted integrated dust at (r, phi)
    note: this is a single data point'''
    pred1 = model(np.array([[r, theita]]), training=False) # NN prediction for integrated dust at r, phi
    pred2 = model(np.array([[r - 1e-4, theita]]), training=False)  # NN prediction for integrated dust at r - delta_r, phi
    return (pred1 - pred2) / 1e-4

# ignoring derivative for now since with a ReLU those will be piecewise constant, so the choice of activation functions will matter there
plt.figure(figsize=(10, 10)) 
X_test_cart = [pol2cart(r,theita) for r,theita in X_test] # turn X_test to cartesian to pass in logdust
intrinsic = [np.exp(logdust(x,y)) for x,y in X_test_cart]
pred = [differentiate4(model1, r, theita) for r,theita in X_test]

intrinsic_asinh = np.arcsinh(intrinsic) # doing log(pred) before but changed to asinh as predictions may be negative 
pred_asinh = np.arcsinh(pred)
applyPlotStyle2()
plt.scatter(intrinsic_asinh, pred_asinh, s=1, color='blue', linestyle='-', linewidth = 0.2, marker = 'D', edgecolor='black') 
plt.xlabel("Intrinsic " + r'$asinh$' + ' ' + r'$\rho(r, \theta)$')
plt.ylabel("Predicted " + r'$asinh$' + ' ' + r'$\rho(r, \theta)$')
lims = [min(np.amin(intrinsic_asinh), np.amin(pred_asinh)), max(np.amax(intrinsic_asinh), np.amax(pred_asinh))]
plt.xlim(lims)
plt.ylim(lims)
plt.plot(lims, lims)
plt.title('Intrinsic vs Predicted')
plt.savefig('plots/typicalintrinsicvspredictedFinal.png', bbox_inches='tight')

# %% [markdown]
# ### Testing: Comparing Networks Predicted Data and Intrinsic Data $\dfrac{d A(r, \theta)}{dr}$ using NN derivative

# %%
import math

def gelu(x):
    return 0.5 * x * (1 + math.erf(x / math.sqrt(2)))
def gelu_derivative(x):
    return

#https://stackoverflow.com/questions/43715047/how-do-i-get-the-weights-of-a-layer-in-keras
# weights are get_weights()[0], biases are get_weights()[1] -> weird...
# get weight matrices 
w_2 = model1.get_layer('dense_1').get_weights()[0]
w_3 = model1.get_layer('dense_2').get_weights()[0]
w_4 = model1.get_layer('dense_3').get_weights()[0]
w_5 = model1.get_layer('predictions').get_weights()[0]
def get_intrinsic_dust_with_NN_derivative(model):
    '''Find instrinsic dust through derivative of neural network'''
    total_layers = HIDDEN_LAYERS + 2
    # get derivative of activation (gelu)
    f_prime =
# Out:
# (512, 1)

# %% [markdown]
# ## Training and Testing a Typical Neural Network with Attenuation Data ($(r, \dfrac{x}{r}, \dfrac{y}{r})$ coordinates)

# %% [markdown]
# ### Training Network

# %%
model2, train_loss2, val_loss2 = train_NN_model(monotonic=False, error=False, num_input=3)

# %%
model2.save('models')

# %%
plt.figure(figsize=(5, 5)) 
plot_NN_loss(train_loss2, val_loss2)

# %% [markdown]
# ### Testing: Comparing Networks Predicted Data and Intrinsic Data $A(r, \dfrac{x}{r}, \dfrac{y}{r})$

# %%
plt.figure(figsize=(5, 5)) 
pred = get_NN_pred(model2, X_test)
plt.scatter(Y_test, pred, s=1, color='blue', linestyle='-', linewidth = 0.1, marker = 'D', edgecolor='black') 
plt.xlabel("Intrinsic dust density " + r'$\rho(r, theita)$')
plt.ylabel("Predicted dust density " + r'$\rho(r, theita)$')
lims = [min(np.amin(Y_test), np.amin(pred)), max(np.amax(Y_test), np.amax(pred))]
plt.xlim(lims)
plt.ylim(lims)
plt.plot(lims, lims)
plt.title('Intrinsic vs Predicted')

# %% [markdown]
# ### Testing: Comparing Networks Predicted Data and Intrinsic Data $\dfrac{d A(r, \dfrac{x}{r}, \dfrac{y}{r})}{dr}$

# %%
# ignoring derivative for now since with a ReLU those will be piecewise constant, so the choice of activation functions will matter there
plt.figure(figsize=(5, 5)) 
X_test_cart = [polWithTwise2cart(r, x_over_r, y_over_r) for r, x_over_r, y_over_r in X_test] # turn X_test to cartesian to pass in logdust
true_dust = [np.exp(logdust(x,y)) for x,y in X_test_cart]
X_test_polar = [cart2pol(x,y) for x,y in X_test_cart]
print(true_dust[0])
test_pred_differentiated = [differentiate(model2, r, theita) for r,theita in X_test_polar]
print(test_pred_differentiated[0])
plt.scatter(true_dust, test_pred_differentiated, s=1, color='blue', linestyle='-', linewidth = 0.1, marker = 'D', edgecolor='black') 
plt.xlabel("Intrinsic dust density " + r'$\rho(r, theita)$')
plt.ylabel("Predicted dust density " + r'$\rho(r, theita)$')
lims = [min(np.amin(true_dust), np.amin(test_pred_differentiated)), max(np.amax(true_dust), np.amax(test_pred_differentiated))]
plt.xlim(lims)
plt.ylim(lims)
plt.plot(lims, lims)
plt.title('Intrinsic vs Predicted')

# %% [markdown]
# ## Training and Testing a Monotonic Neural Network with Attenuation Data (Polar coordinates)

# %% [markdown]
# ### Training Network

# %%
# laod intrinsic_integrated_polar.npz before running this
BATCH_SIZE = 100
MIN_GROUP_SIZE = 4
EPOCHS = 100
model3, train_loss_monotonic3, val_loss_monotonic3 = train_NN_model(monotonic=True, error=False, num_input=2, optimizer=optimizer2)

# %%
model3.save("model3")
# Out:
# INFO:tensorflow:Assets written to: model3/assets

# %%
# model3 = keras.models.load_model("model3")
plt.figure(figsize=(5, 5)) 
plot_NN_loss(train_loss_monotonic3, val_loss_monotonic3)

# %%
rcParams.update({'font.size': 20})
plt.figure(figsize=(15, 8)) 
pred = get_min_max_model_predictions(model3, X_test, training=False)
pred_asinh = np.arcsinh(pred)
Y_test_asinh = np.arcsinh(Y_test)
plt.subplot(1, 2, 1)
plt.scatter(Y_test, pred, s=1, color='blue', linestyle='-', linewidth = 0.1, marker = 'D', edgecolor='black') 
plt.xlabel("Intrinsic " + r'$A(r, theita)$')
plt.ylabel("Predicted " + r'$A(r, theita)$')
lims = [min(np.amin(Y_test), np.amin(pred)), max(np.amax(Y_test), np.amax(pred))]
plt.xlim(lims)
plt.ylim(lims)
plt.plot(lims, lims)
plt.title('Intrinsic vs Predicted ' +  r'$A(r, \theta)$')
plt.subplot(1, 2, 2)
plt.scatter(Y_test_asinh, pred_asinh, s=1, color='blue', linestyle='-', linewidth = 0.2, marker = 'D', edgecolor='black') 
plt.xlabel("Intrinsic " + r'$asinh A(r, \theta)$')
plt.ylabel("Predicted " + r'$asinh A(r, \theta)$')
lims = [min(np.amin(Y_test_asinh), np.amin(pred_asinh)), max(np.amax(Y_test_asinh), np.amax(pred_asinh))]
plt.xlim(lims)
plt.ylim(lims)
plt.plot(lims, lims)
plt.title('Intrinsic vs Predicted Data ' +  r'$asinh A(r, \theta)$')
plt.tight_layout(pad=3.0)
plt.savefig('plots/monotonicintrinsicvspredicted.png', bbox_inches='tight')

# %%
# It can be used to reconstruct the model identically.
def pol2cart(r, theita):
    '''Return cartesian coordinate from polar coordinate'''
    x = r * np.cos(theita)
    y = r * np.sin(theita)
    return [x, y]
reload_model = keras.models.load_model("model3")
X_test_cart = np.array([np.array(pol2cart(r,theita)) for r,theita in X_test])
# plot_map_panels(X_test_cart, Y_test, 'min-max', reload_model, error=False)

pred = get_min_max_model_predictions(reload_model, X_test, training=False)
plt.figure(figsize=(20, 5))
# start plotting
xlim, ylim = [X_MIN, X_MAX], [Y_MIN, Y_MAX]
plt.subplot(1, 3, 1)
plt.scatter(X_test_cart[:, 0], X_test_cart[:, 1], c=Y_test, cmap='coolwarm', s=3)
plt.xlabel(r'$x$')
plt.ylabel(r'$y$')
plt.colorbar(label=r'$ A(x, y)$')
plt.xlim(xlim)
plt.ylim(ylim)
plt.title('Testing set: Actual')
plt.subplot(1, 3, 2)
plt.scatter(X_test_cart[:, 0], X_test_cart[:, 1], c=pred, 
            cmap='coolwarm', s=3)
plt.xlabel(r'$x$')
plt.ylabel(r'$y$')
plt.colorbar(label=r'$ A(x, y)$')
plt.xlim(xlim)
plt.ylim(ylim)
plt.title('Testing set: Predicted')
plt.subplot(1, 3, 3) # shifting colormap    
plt.scatter(np.append(X_test_cart[:, 0], [-5, -5]), np.append(X_test_cart[:, 1], [-5, -5]), 
            c=np.append(pred - Y_test, [-(np.amax(np.abs(Y_test - pred))), np.amax(np.abs(Y_test - pred))]), 
            cmap='coolwarm', s=3) #tab20
plt.xlabel(r'$x$')
plt.ylabel(r'$y$')
plt.colorbar(label='Residual')
plt.xlim(xlim)
plt.ylim(ylim)
plt.title('Testing set: Actual vs Predicted Residual')
plt.tight_layout()
# Out:
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.

# %%
X_test_cart = np.array([np.array(pol2cart(r,theita)) for r,theita in X_test])
xlim, ylim = [X_MIN, X_MAX], [Y_MIN, Y_MAX]
rcParams.update({'font.size': 30})
pred = get_min_max_model_predictions(model3, X_test, training=False)
applyPlotStyle2()
fig, ax = plt.subplots(1, 3, figsize=(40,10))
pcm = ax[0].scatter(X_test_cart[:, 0], X_test_cart[:, 1], c=Y_test, norm=matplotlib.colors.PowerNorm(gamma=.4), cmap='coolwarm', s = 15)
ax[0].set_xlabel(r'$x$')
ax[0].set_ylabel(r'$y$')
ax[0].set_xlim(xlim)
ax[0].set_ylim(ylim)
ax[0].set_title('Intrinsic Data')
fig.colorbar(pcm, ax=ax[0], label=r'$A_i(x, y)$') 
# im = plt.imshow(X_test_cart, cmap='coolwarm')
pcm = ax[1].scatter(X_test_cart[:, 0], X_test_cart[:, 1], c=pred, norm=matplotlib.colors.PowerNorm(gamma=.4), cmap='coolwarm', s = 15)
ax[1].set_xlabel(r'$x$')
ax[1].set_ylabel(r'$y$')
ax[1].set_xlim(xlim)
ax[1].set_ylim(ylim)
ax[1].set_title('Predicted Data')
fig.colorbar(pcm, ax=ax[1], label=r'$A_p(x, y)$') 
pcm = ax[2].scatter(np.append(X_test_cart[:, 0], [-5, -5]), np.append(X_test_cart[:, 1], [-5, -5]), c=np.append(Y_test - pred, [-(np.amax(np.abs(Y_test - pred))), np.amax(np.abs(Y_test - pred))]), cmap='coolwarm', s = 15)
ax[2].set_xlabel(r'$x$')
ax[2].set_ylabel(r'$y$')
ax[2].set_xlim(xlim)
ax[2].set_ylim(ylim)
ax[2].set_title('Residual')
fig.colorbar(pcm, ax=ax[2], label=r'$A_i(x, y) - A_p(x, y)$') 
plt.tight_layout()
plt.savefig('plots/3panelall2.png', bbox_inches='tight')
print([-(np.amax(np.abs(Y_test - pred))), np.amax(np.abs(Y_test - pred))])
# Out:
# [-4.7967234, 4.7967234]

# %%
def pol2cart(r, theita):
    '''Return cartesian coordinate from polar coordinate'''
    x = r * np.cos(theita)
    y = r * np.sin(theita)
    return [x, y]

def differentiate5(model, r, theita):
    '''Return dA(r, phi)/r ie. return predicted integrated dust at (r - delta_r, phi) subtracted from predicted integrated dust at (r, phi)
    note: this is a single data point'''
    pred1 = get_min_max_model_predictions(model, np.array([[r, theita]]), training=False) # NN prediction for integrated dust at r, phi
    pred2 = get_min_max_model_predictions(model, np.array([[r - 0.5, theita]]), training=False)  # NN prediction for integrated dust at r - delta_r, phi
    return (pred1 - pred2) / 0.5

plt.figure(figsize=(7, 7)) 
X_test_cart = [pol2cart(r,theita) for r,theita in X_test] # turn X_test to cartesian to pass in logdust
true_dust = [np.exp(logdust(x,y)) for x,y in X_test_cart]
print(true_dust[0])
test_pred_differentiated = [differentiate5(model3, r, theita) for r,theita in X_test]
print(test_pred_differentiated[0])

pred_asinh = np.arcsinh(test_pred_differentiated)
intrinsic_asinh = np.arcsinh(true_dust)

plt.scatter(intrinsic_asinh, pred_asinh, s=1, color='blue', linestyle='-', linewidth = 0.1, marker = 'D', edgecolor='black') 
plt.xlabel("Intrinsic " + r'$asinh$' + ' ' + r'$\rho(r, theita)$')
plt.ylabel("Predicted " + r'$asinh$' + ' ' + r'$\rho(r, theita)$')
lims = [min(np.amin(intrinsic_asinh), np.amin(pred_asinh)), max(np.amax(intrinsic_asinh), np.amax(pred_asinh))]
plt.xlim(lims)
plt.ylim(lims)
plt.plot(lims, lims)
plt.title('Intrinsic vs Predicted')
# Out:
# 1.2319510873235588
# tf.Tensor([1.313097], shape=(1,), dtype=float32)
# Text(0.5, 1.0, 'Intrinsic vs Predicted')

# %% [markdown]
# # Model 4: Partially Monotone Neural Network

# %% [markdown]
# **Partially monotone neural networks (PMNNs)** enforce a monotonicity (i.e. non-negative gradient) constraint on $\geq 1$ of the inputs to the network. In this case, we want to use this ability to enforce monotonicity in $g(\mathbf{x})$ in the radial direction (i.e. as a function of $r$) but not in the angular direction. This can be done by forcing the weights associated with the monotonic parameter to always be non-negative and ensuring that the activation functions used also are non-negative. This can also be accompanied by changes to the network architecture

# %%
# define and fit partially monotone neural network
